# %% [markdown]
# <a href="https://colab.research.google.com/github/MoonlightO2/Vehicle-Leasing-Data/blob/main/Car_Lease_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Car Leasing : Data Analysis of Used Cars**
# ***Article***: https://medium.com/@ramananrohit4/car-leasing-data-analysis-of-used-cars-46136c21e40c
#
# ***Dataset***: https://data.world/data-society/used-cars-data

# %% [markdown]
# ### **Importing Libraries and Data**

# %%
import pandas as pd
import numpy as np
import re
import gc

# %%
file = '/content/drive/MyDrive/Projects/Portfolio/Vehicles/Car leasing/Car Lease data.csv'

# %%
data = pd.read_csv('https://query.data.world/s/xmd6vagrr4ha5nzc5z675rut7l374x?dws=00000',encoding="Latin-1")
print('Shape: ', data.shape, '\n')
print('Columns: ', data.columns.tolist(), '\n')
data.head()
# Out:
# Shape:  (371528, 20)
#
# Columns:  ['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand', 'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode', 'lastSeen']
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# ...

# %%
for column_name, values in data.items():
    unique_values = set(values)
    num_unique_values = len(unique_values)

    print(f"Column: {column_name}")
    print(f"Unique Values: {unique_values}")
    print(f"Number of Unique Values: {num_unique_values}\n")
# Out:
# Column: dateCrawled
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Column: vehicleType
# Unique Values: {nan, 'kleinwagen', 'suv', 'bus', 'limousine', 'andere', 'cabrio', 'kombi', 'coupe'}
# Number of Unique Values: 9
#
# Column: yearOfRegistration
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 371528 entries, 0 to 371527
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   dateCrawled          371528 non-null  object
#  1   name                 371528 non-null  object
#  2   seller               371528 non-null  object
#  3   offerType            371528 non-null  object
#  4   price                371528 non-null  int64
#  5   abtest               371528 non-null  object
#  6   vehicleType          333659 non-null  object
#  7   yearOfRegistration   371528 non-null  int64
#  8   gearbox              351319 non-null  object
#  9   powerPS              371528 non-null  int64
#  10  model                351044 non-null  object
#  11  kilometer            371528 non-null  int64
#  12  monthOfRegistration  371528 non-null  int64
#  13  fuelType             338142 non-null  object
#  14  brand                371528 non-null  object
# ...

# %% [markdown]
# ### **Data Cleaning**

# %%
#duplicate check
print('Shape: ', data.shape, '\n')
data.duplicated().sum()
# Out:
# Shape:  (371528, 20)
# 4

# %%
#removing duplicate
data=data[~data.duplicated()]
print('Shape: ', data.shape, '\n')
print('Columns: ', data.columns.tolist(), '\n')
data.head()
# Out:
# Shape:  (371524, 20)
#
# Columns:  ['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest', 'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model', 'kilometer', 'monthOfRegistration', 'fuelType', 'brand', 'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode', 'lastSeen']
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# ...

# %%
# Mapping old column names to new column names
column_mapping = {
    'dateCrawled': 'DateTime',
    'name': 'Car Name',
    'seller': 'Seller',
    'offerType': 'Offer Type',
    'price': 'Price',
    'abtest': 'AB Test',
    'vehicleType': 'Vehicle Type',
    'yearOfRegistration': 'Year of Registration',
    'gearbox': 'Gearbox',
    'powerPS': 'Power PS',
    'model': 'Model',
    'kilometer': 'Kilometer',
    'monthOfRegistration': 'Month of Registration',
    'fuelType': 'Fuel Type',
    'brand': 'Brand',
    'notRepairedDamage': 'Not Repaired Damage',
    'dateCreated': 'Date Created',
    'nrOfPictures': 'Pictures',
    'postalCode': 'Postal Code',
    'lastSeen': 'Last Seen'
}

# Rename columns using the mapping
data.rename(columns=column_mapping, inplace=True)

print('Shape: ', data.shape, '\n')
print('Columns: ', data.columns.tolist(), '\n')
# Out:
# Shape:  (371524, 20)
#
# Columns:  ['DateTime', 'Car Name', 'Seller', 'Offer Type', 'Price', 'AB Test', 'Vehicle Type', 'Year of Registration', 'Gearbox', 'Power PS', 'Model', 'Kilometer', 'Month of Registration', 'Fuel Type', 'Brand', 'Not Repaired Damage', 'Date Created', 'Pictures', 'Postal Code', 'Last Seen']

# %%
data.drop(columns=['Pictures', 'Postal Code', 'Last Seen'], inplace=True)

# %%
# Splitting date and time into two columns
data[['Date', 'Time']] = data['DateTime'].str.split(' ', 1, expand=True)

# Dropping the original datetime column if needed
data.drop(columns=['DateTime'], inplace=True)

print('Shape: ', data.shape, '\n')
print('Columns: ', data.columns.tolist(), '\n')
# Out:
# <ipython-input-51-1225b0d810b3>:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   data[['Date', 'Time']] = data['DateTime'].str.split(' ', 1, expand=True)
# Shape:  (371524, 18)
#
# Columns:  ['Car Name', 'Seller', 'Offer Type', 'Price', 'AB Test', 'Vehicle Type', 'Year of Registration', 'Gearbox', 'Power PS', 'Model', 'Kilometer', 'Month of Registration', 'Fuel Type', 'Brand', 'Not Repaired Damage', 'Date Created', 'Date', 'Time']

# %%
data = data.apply(lambda x: x.str.title().str.replace('_', ' ') if x.dtype == "object" else x)
data.head()
# Out:
#                          Car Name  Seller Offer Type  Price AB Test  \
# 0                      Golf 3 1.6  Privat    Angebot    480    Test
# 1            A5 Sportback 2.7 Tdi  Privat    Angebot  18300    Test
# 2  Jeep Grand Cherokee "Overland"  Privat    Angebot   9800    Test
# 3              Golf 4 1 4  3Türer  Privat    Angebot   1500    Test
# 4  Skoda Fabia 1.4 Tdi Pd Classic  Privat    Angebot   3600    Test
#
#   Vehicle Type  Year of Registration    Gearbox  Power PS  Model  Kilometer  \
# 0          NaN                  1993    Manuell         0   Golf     150000
# 1        Coupe                  2011    Manuell       190    NaN     125000
# 2          Suv                  2004  Automatik       163  Grand     125000
# 3   Kleinwagen                  2001    Manuell        75   Golf     150000
# 4   Kleinwagen                  2008    Manuell        69  Fabia      90000
#
#    Month of Registration Fuel Type       Brand Not Repaired Damage  \
# ...

# %%
columns = ['Date', 'Time', 'Car Name', 'Model', 'Vehicle Type', 'Year of Registration',
                   'Month of Registration', 'Seller', 'Offer Type', 'Price', 'AB Test', 'Gearbox',
                   'Power PS', 'Kilometer', 'Fuel Type', 'Brand', 'Not Repaired Damage',
                   'Date Created', 'Pictures', 'Postal Code', 'Last Seen']

# Reorder the columns
data = data.reindex(columns=columns)

# Now you can save the DataFrame to a CSV file
data.to_csv(file, index=False)

print('Data Cleaning and File creation successful..!', file)
# Out:
# Data Cleaning and File creation successful..! /content/drive/MyDrive/Projects/Portfolio/Vehicles/Car leasing/Car Lease data.csv

# %%
# Perform garbage collection
gc.collect()
print('Memory cleared..!')
# Out:
# Memory cleared..!
